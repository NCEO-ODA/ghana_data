# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from data_analysis.tseries_funcs import get_one_region_landcover

# %% [markdown]
# # Plots for districts.
#
# Set the value of `region_where` to have the desired district. For example, here we use `Garu Tempane` (Upper East) as an example. We first reserve a figure with 4 rows sharing the `x` axis (time).

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(12,12))
axs = axs.flatten()
region_where = "HRname='Garu Tempane'"
year = 2020

for iplot, (product, variable) in enumerate(zip(
                            ["ERA5", "TAMSAT", "TAMSAT", "MODIS"],
                            ["t2m_mean", "precip", "smc_avail_top", "Fpar_500m"])):
    _ = get_one_region_landcover(product, variable, year, region_where, ax=axs[iplot])
fig.tight_layout()
fig.savefig("Garu_Tempane_2020.pdf", dpi=150, bbox_inches="tight")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Roboto Condensed

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(12,12))
axs = axs.flatten()
region_where = "HRname='Kintampo North'"
year = 2020

for iplot, (product, variable) in enumerate(zip(
                            ["ERA5", "TAMSAT", "TAMSAT", "MODIS"],
                            ["t2m_mean", "precip", "smc_avail_top", "Fpar_500m"])):
    _ = get_one_region_landcover(product, variable, year, region_where, ax=axs[iplot])
fig.tight_layout()
fig.savefig("Kintampo_North_2020.pdf", dpi=150, bbox_inches="tight")

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(12,12))
axs = axs.flatten()
region_where = "HRname='Jomoro'"
year = 2020

for iplot, (product, variable) in enumerate(zip(
                            ["ERA5", "TAMSAT", "TAMSAT", "MODIS"],
                            ["t2m_mean", "precip", "smc_avail_top", "Fpar_500m"])):
    _ = get_one_region_landcover(product, variable, year, region_where, ax=axs[iplot])
fig.tight_layout()
fig.savefig("Jomoro_2020.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# The above code has taken the region  of interest, and used the Copernicus Land Service Land Cover map to filter out urban areas, lakes, and provide an average of the variable of interest on a monthly basis, comparing it with the historical long term  average (LTA).

# %% [markdown]
# ## For regions
#
# For regions, you may run into out of memory errors running this on Binder. You need to do two things:
# 1. set `region_ds = "GHA_admbndp1_1m_GAUL.shp"` in `get_one_region_landcover`
# 2. Set `region_where` to be `"HRname='Upper West'"`.

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(12,12))
axs = axs.flatten()
region_where = "HRname='Upper West'"
year = 2020

for iplot, (product, variable) in enumerate(zip(
                            ["ERA5", "TAMSAT", "TAMSAT", "MODIS"],
                            ["t2m_mean", "precip", "smc_avail_top", "Fpar_500m"])):
    _ = get_one_region_landcover(product, variable, year, region_where,  region_ds = "GHA_admbndp1_1m_GAUL.shp", 
                                 ax=axs[iplot])
